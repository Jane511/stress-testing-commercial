# %% [markdown]
# # 02 Stress Engine
#
# Apply the scenarios to base PD, LGD, EAD, and Expected Loss.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.engine import aggregate_results, apply_stress_scenarios
from src.loaders import load_inputs

portfolio, scenarios = load_inputs()
results = apply_stress_scenarios(portfolio, scenarios)
results[["scenario_name", "facility_id", "base_pd", "stressed_pd", "base_lgd", "stressed_lgd", "base_ead", "stressed_ead", "stressed_expected_loss"]].head(12)

# %%
aggregate_results(results, ["scenario_name", "segment"])

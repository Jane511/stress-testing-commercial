# %% [markdown]
# # 01 Scenario Design
#
# Review the reusable scenario table and the stress dimensions applied by the engine.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.loaders import load_scenarios
from src.validation import validate_scenario_table

scenarios = load_scenarios()
validate_scenario_table(scenarios)
scenarios

# %% [markdown]
# The scenario table controls PD, LGD, EAD, collateral, recovery-delay, industry, property, and concentration overlays.

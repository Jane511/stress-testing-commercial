# %% [markdown]
# # 04 Reporting
#
# Run the full pipeline and inspect the reporting-ready outputs.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.run_pipeline import run_pipeline

output_paths = run_pipeline()
output_paths

# %%
import pandas as pd

pd.read_csv(ROOT / "outputs" / "tables" / "portfolio_stress_summary.csv")

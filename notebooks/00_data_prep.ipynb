# %% [markdown]
# # 00 Data Prep
#
# Load the synthetic upstream risk component output and review the facility-level fields used by the stress engine.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.loaders import load_portfolio
from src.validation import validate_portfolio_input

portfolio = load_portfolio()
validate_portfolio_input(portfolio)
portfolio.head()

# %%
portfolio.groupby(["segment", "product"], as_index=False)["base_ead"].sum()
